# %% [markdown]
# # import libraries

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import date , datetime

# %% [markdown]
# # getting files

# %%
project_path = os.getcwd()
file_path = f'{project_path}\\data\\'
seprate_file_path = file_path+'\\seprate\\'

# %%
filelist = seprate_file_path
stock_file_names = os.listdir(filelist)

# prints all files
print(stock_file_names)
# Out:
# ['AAPL.csv', 'AMZN.csv', 'GOOG.csv', 'NFLX.csv']

# %% [markdown]
# # concating all records in stock

# %%
stock = []
count = 0
length = len(stock_file_names)
print('')
print('--------------------- Conversion Started ---------------------')
print('')
for i in stock_file_names:
    print(f'File Name {count+1}):- ', i)
    file_divide = i.split('.')
    stock_name = file_divide[0]
    #print(stock_name)
    stock_data = pd.read_csv(seprate_file_path+f'{i}')
    stock_data['stock_name'] = f'{stock_name}'
    #print('')
    #print(stock_data)
    stock.append(stock_data)
    count+=1
print('')
print('--------------------- Conversion Finished ---------------------')
print('')
stock = pd.concat(stock,ignore_index=1)
# Out:
# --------------------- Conversion Started ---------------------
#
# File Name 1):-  AAPL.csv
# File Name 2):-  AMZN.csv
# File Name 3):-  GOOG.csv
# File Name 4):-  NFLX.csv
#
# --------------------- Conversion Finished ---------------------

# %% [markdown]
# # show stock data / load stock data

# %%
print('stock is running')
# Out:
# stock is running

# %%
stock
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      2010-01-04    7.622500    7.660714    7.585000    7.643214    6.544688
# 1      2010-01-05    7.664286    7.699643    7.616071    7.656429    6.556003
# 2      2010-01-06    7.656429    7.686786    7.526786    7.534643    6.451722
# 3      2010-01-07    7.562500    7.571429    7.466071    7.520714    6.439793
# 4      2010-01-08    7.510714    7.571429    7.466429    7.570714    6.482607
# ...           ...         ...         ...         ...         ...         ...
# 12279  2022-02-24  355.089996  390.730011  354.720001  390.029999  390.029999
# 12280  2022-02-25  386.609985  391.290009  375.579987  390.799988  390.799988
# 12281  2022-02-28  387.329987  397.750000  382.130005  394.519989  394.519989
# 12282  2022-03-01  391.600006  395.000000  383.709991  386.239990  386.239990
# 12283  2022-03-02  388.929993  389.220001  375.209991  380.029999  380.029999
#
#           Volume stock_name
# 0      493729600       AAPL
# 1      601904800       AAPL
# 2      552160000       AAPL
# 3      477131200       AAPL
# 4      447610800       AAPL
# ...          ...        ...
# 12279    7068700       NFLX
# 12280    4841600       NFLX
# 12281    5035000       NFLX
# 12282    3290400       NFLX
# 12283    5356800       NFLX
#
# [12284 rows x 8 columns]

# %% [markdown]
# # stock describe

# %%
stock.shape
# Out:
# (12284, 8)

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12284 entries, 0 to 12283
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        12284 non-null  object
#  1   Open        12284 non-null  float64
#  2   High        12284 non-null  float64
#  3   Low         12284 non-null  float64
#  4   Close       12284 non-null  float64
#  5   Adj Close   12284 non-null  float64
#  6   Volume      12284 non-null  int64
#  7   stock_name  12284 non-null  object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 767.9+ KB

# %% [markdown]
# # removing all null values

# %%
stock.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Adj Close     0
# Volume        0
# stock_name    0
# dtype: int64

# %%
### =>  getting percentage of null data values from stock

# %%
null_vals = stock.isnull().sum() / stock.shape[0] * 100

# %%
null_vals
# Out:
# Date          0.0
# Open          0.0
# High          0.0
# Low           0.0
# Close         0.0
# Adj Close     0.0
# Volume        0.0
# stock_name    0.0
# dtype: float64

# %% [markdown]
# ### =>  droping null values from stock

# %%
null_val_cols = null_vals[null_vals > 30].keys()

# %%
stock.drop(null_val_cols,axis=1,inplace=True)

# %%
stock
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      2010-01-04    7.622500    7.660714    7.585000    7.643214    6.544688
# 1      2010-01-05    7.664286    7.699643    7.616071    7.656429    6.556003
# 2      2010-01-06    7.656429    7.686786    7.526786    7.534643    6.451722
# 3      2010-01-07    7.562500    7.571429    7.466071    7.520714    6.439793
# 4      2010-01-08    7.510714    7.571429    7.466429    7.570714    6.482607
# ...           ...         ...         ...         ...         ...         ...
# 12279  2022-02-24  355.089996  390.730011  354.720001  390.029999  390.029999
# 12280  2022-02-25  386.609985  391.290009  375.579987  390.799988  390.799988
# 12281  2022-02-28  387.329987  397.750000  382.130005  394.519989  394.519989
# 12282  2022-03-01  391.600006  395.000000  383.709991  386.239990  386.239990
# 12283  2022-03-02  388.929993  389.220001  375.209991  380.029999  380.029999
#
#           Volume stock_name
# 0      493729600       AAPL
# 1      601904800       AAPL
# 2      552160000       AAPL
# 3      477131200       AAPL
# 4      447610800       AAPL
# ...          ...        ...
# 12279    7068700       NFLX
# 12280    4841600       NFLX
# 12281    5035000       NFLX
# 12282    3290400       NFLX
# 12283    5356800       NFLX
#
# [12284 rows x 8 columns]

# %%
stock.isnull().sum() / stock.shape[0] * 100
# Out:
# Date          0.0
# Open          0.0
# High          0.0
# Low           0.0
# Close         0.0
# Adj Close     0.0
# Volume        0.0
# stock_name    0.0
# dtype: float64

# %%
stock.dropna(inplace=True)

# %%
stock.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Adj Close     0
# Volume        0
# stock_name    0
# dtype: int64

# %%
stock
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      2010-01-04    7.622500    7.660714    7.585000    7.643214    6.544688
# 1      2010-01-05    7.664286    7.699643    7.616071    7.656429    6.556003
# 2      2010-01-06    7.656429    7.686786    7.526786    7.534643    6.451722
# 3      2010-01-07    7.562500    7.571429    7.466071    7.520714    6.439793
# 4      2010-01-08    7.510714    7.571429    7.466429    7.570714    6.482607
# ...           ...         ...         ...         ...         ...         ...
# 12279  2022-02-24  355.089996  390.730011  354.720001  390.029999  390.029999
# 12280  2022-02-25  386.609985  391.290009  375.579987  390.799988  390.799988
# 12281  2022-02-28  387.329987  397.750000  382.130005  394.519989  394.519989
# 12282  2022-03-01  391.600006  395.000000  383.709991  386.239990  386.239990
# 12283  2022-03-02  388.929993  389.220001  375.209991  380.029999  380.029999
#
#           Volume stock_name
# 0      493729600       AAPL
# 1      601904800       AAPL
# 2      552160000       AAPL
# 3      477131200       AAPL
# 4      447610800       AAPL
# ...          ...        ...
# 12279    7068700       NFLX
# 12280    4841600       NFLX
# 12281    5035000       NFLX
# 12282    3290400       NFLX
# 12283    5356800       NFLX
#
# [12284 rows x 8 columns]

# %% [markdown]
# # reshort stock data

# %%
stock = stock[['Date','stock_name','Open','High','Low','Close','Volume']]
stock
# Out:
#              Date stock_name        Open        High         Low       Close  \
# 0      2010-01-04       AAPL    7.622500    7.660714    7.585000    7.643214
# 1      2010-01-05       AAPL    7.664286    7.699643    7.616071    7.656429
# 2      2010-01-06       AAPL    7.656429    7.686786    7.526786    7.534643
# 3      2010-01-07       AAPL    7.562500    7.571429    7.466071    7.520714
# 4      2010-01-08       AAPL    7.510714    7.571429    7.466429    7.570714
# ...           ...        ...         ...         ...         ...         ...
# 12279  2022-02-24       NFLX  355.089996  390.730011  354.720001  390.029999
# 12280  2022-02-25       NFLX  386.609985  391.290009  375.579987  390.799988
# 12281  2022-02-28       NFLX  387.329987  397.750000  382.130005  394.519989
# 12282  2022-03-01       NFLX  391.600006  395.000000  383.709991  386.239990
# 12283  2022-03-02       NFLX  388.929993  389.220001  375.209991  380.029999
#
#           Volume
# 0      493729600
# 1      601904800
# 2      552160000
# 3      477131200
# 4      447610800
# ...          ...
# 12279    7068700
# 12280    4841600
# 12281    5035000
# 12282    3290400
# 12283    5356800
#
# [12284 rows x 7 columns]

# %%
unique_stocks = stock.stock_name.unique()
unique_stocks
# Out:
# array(['AAPL', 'AMZN', 'GOOG', 'NFLX'], dtype=object)

# %%
stock[(stock.stock_name == 'AAPL')].sample(frac=0.01)
# Out:
#             Date stock_name        Open        High         Low       Close  \
# 352   2011-05-26       AAPL   11.998929   12.031786   11.943929   11.964286
# 1702  2016-10-06       AAPL   28.424999   28.584999   28.282499   28.472500
# 2207  2018-10-09       AAPL   55.910000   56.817501   55.562500   56.717499
# 584   2012-04-27       AAPL   21.609644   21.649286   21.446428   21.535713
# 1069  2014-04-03       AAPL   19.335358   19.375000   19.201429   19.242500
# 1542  2016-02-19       AAPL   24.000000   24.190001   23.950001   24.010000
# 2158  2018-07-31       AAPL   47.575001   48.035000   47.334999   47.572498
# 102   2010-06-01       AAPL    9.274643    9.497857    9.248571    9.315357
# 2682  2020-08-28       AAPL  126.012497  126.442497  124.577499  124.807503
# 992   2013-12-11       AAPL   20.250000   20.391787   19.988930   20.048571
# 396   2011-07-29       AAPL   13.844286   14.112500   13.714286   13.945714
# 1266  2015-01-14       AAPL   27.260000   27.622499   27.125000   27.450001
# 1661  2016-08-09       AAPL   27.057501   27.235001   27.002501   27.202499
# 140   2010-07-26       AAPL    9.285714    9.289286    9.203929    9.260000
# 2638  2020-06-26       AAPL   91.102501   91.330002   88.254997   88.407501
# 779   2013-02-07       AAPL   16.544643   16.785713   16.218571   16.722143
# 2347  2019-05-02       AAPL   52.459999   53.162498   52.032501   52.287498
# 282   2011-02-15       AAPL   12.828214   12.856071   12.769643   12.853571
# 2148  2018-07-17       AAPL   47.437500   47.967499   47.299999   47.862499
# 2522  2020-01-10       AAPL   77.650002   78.167503   77.062500   77.582497
# 2369  2019-06-04       AAPL   43.860001   44.957500   43.630001   44.910000
# 2116  2018-05-31       AAPL   46.805000   47.057499   46.535000   46.717499
# 3052  2022-02-16       AAPL  171.850006  173.339996  170.050003  172.550003
# 2760  2020-12-18       AAPL  128.960007  129.100006  126.120003  126.660004
# 1706  2016-10-12       AAPL   29.337500   29.495001   29.187500   29.334999
# 2226  2018-11-05       AAPL   51.075001   51.097500   49.542500   50.397499
# 100   2010-05-27       AAPL    8.950000    9.067500    8.896786    9.048214
# 263   2011-01-19       AAPL   12.441071   12.450000   12.031429   12.101429
# 1625  2016-06-17       AAPL   24.155001   24.162500   23.825001   23.832500
# 1162  2014-08-15       AAPL   24.475000   24.547501   24.215000   24.495001
# 64    2010-04-07       AAPL    8.555357    8.640000    8.523571    8.592857
#
#           Volume
# 352    222560800
# 1702   115117200
# 2207   107564000
# 584    406722400
# 1069   162344000
# 1542   141496800
# 2158   157492000
# 102    876472800
# 2682   187630000
# 992    359718800
# 396    632584400
# 1266   195826400
# 1661   105260800
# 140    420551600
# 2638   205256800
# 779    704580800
# 2347   127985200
# 282    284174800
# 2148    62138000
# 2522   140644800
# 2369   123872000
# 2116   109931200
# 3052    61177400
# 2760   192541500
# 1706   150347200
# 2226   264654800
# 100    666282400
# 263   1135612800
# 1625   244032800
# 1162   195804000
# 64     628502000

# %%
stock_keys = stock.drop(['Date','stock_name'],axis=1).keys()
color = ['c','g','r','k','#EC008C']

# %%
stock_keys
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
color
# Out:
# ['c', 'g', 'r', 'k', '#EC008C']

# %%
datetime = datetime.now()
current_time_str= f'{datetime.day}.{datetime.month}.{datetime.year}({datetime.hour}.{datetime.minute}.{datetime.second})'
print(current_time_str)
desired_folder = f'{project_path}\\charts\\'
os.makedirs(f'{desired_folder}\\{current_time_str}')
# Out:
# 22.4.2022(13.1.25)

# %%
count= 0
for i in unique_stocks:
    print(f'{count+1}). File start :- ',i)
    condition = stock[(stock.stock_name == i)]
    condition = condition.sample(frac=0.01)
    print(f'{i} :- ploting executed')
    fig , ax = plt.subplots(nrows=1,ncols=5,figsize=(60,8))
    col_count = 0
    dot = '.'
    for stk_name in range(0,len(stock_keys)):
        for graph_color in range(0,len(color)):
            if (stk_name == graph_color):
                ax[col_count].plot(condition['Date'],condition[stock_keys[stk_name]],c=f'{color[graph_color]}')
                ax[col_count].set_title(f'{i} Date vs {stock_keys[stk_name]}', fontstyle='italic')
                ax[col_count].set_xlabel('Date')
                ax[col_count].set_ylabel(f'{stock_keys[stk_name]}')
                col_count +=1
                
    print('---------------- File Saving Start----------------')
    graphsave_folder = desired_folder+current_time_str+'\\'
    file_datetime = datetime.now()
    file_current_time_str= f'{file_datetime.day}.{file_datetime.month}.{file_datetime.year}({file_datetime.hour}.{file_datetime.minute}.{file_datetime.second})'
    plt.savefig(graphsave_folder + f'{i}_{file_current_time_str}.png')
    print(f'{i} figure saved successfully')
    
    print(f'{i} show ploting start')
    plt.show()
    print(f'{i} ploting done')

    print('Other file now executing')
    print('-------------------------------------------------')
    print('')
    count +=1

print('File Finished')
# Out:
# 1). File start :-  AAPL
# AAPL :- ploting executed
# ---------------- File Saving Start----------------
# AAPL figure saved successfully
# AAPL show ploting start
# AAPL ploting done
# Other file now executing
# -------------------------------------------------
#
# 2). File start :-  AMZN
# AMZN :- ploting executed
# ---------------- File Saving Start----------------
# AMZN figure saved successfully
# AMZN show ploting start
# AMZN ploting done
# Other file now executing
# -------------------------------------------------
#
# 3). File start :-  GOOG
# GOOG :- ploting executed
# ---------------- File Saving Start----------------
# GOOG figure saved successfully
# GOOG show ploting start
# GOOG ploting done
# Other file now executing
# -------------------------------------------------
#
# 4). File start :-  NFLX
# NFLX :- ploting executed
# ---------------- File Saving Start----------------
# NFLX figure saved successfully
# NFLX show ploting start
# NFLX ploting done
# Other file now executing
# -------------------------------------------------
#
# File Finished
